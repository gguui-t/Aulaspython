# %%
def tipo_produto(produto):
    produto = produto.upper() # funçao upper letra maiuscula 
    if 'BEB' in produto:
        return 'alcolico'
    elif 'BSA' in produto:
        return 'vinho'
    else:
        return None
    

produtos = ['beb46275','TFA23962','TFA64715','TFA69555','TFA56743','BSA45510','TFA44968','CAR75448','CAR23596','CAR13490','BEB21365','BEB31623','BSA62419','BEB73344','TFA20079','BEB80694','BSA11769','BEB19495','TFA14792','TFA78043','BSA33484','BEB97471','BEB62362','TFA27311','TFA17715','BEB85146','BEB48898','BEB79496','CAR38417','TFA19947','TFA58799','CAR94811','BSA59251','BEB15385','BEB24213','BEB56262','BSA96915','CAR53454','BEB75073']

for produto in produtos:
    tipo = tipo_produto(produto)
    if tipo=='alcolico':
        print(f'Enviar esse {produto} para o setor de bebidas alcolicas')
    elif tipo=='vinho':
        print(f'Enviar esse {produto} para o setor de vinhos')
# Out:
# Enviar esse beb46275 para o setor de bebidas alcolicas
# Enviar esse BSA45510 para o setor de vinhos
# Enviar esse BEB21365 para o setor de bebidas alcolicas
# Enviar esse BEB31623 para o setor de bebidas alcolicas
# Enviar esse BSA62419 para o setor de vinhos
# Enviar esse BEB73344 para o setor de bebidas alcolicas
# Enviar esse BEB80694 para o setor de bebidas alcolicas
# Enviar esse BSA11769 para o setor de vinhos
# Enviar esse BEB19495 para o setor de bebidas alcolicas
# Enviar esse BSA33484 para o setor de vinhos
# Enviar esse BEB97471 para o setor de bebidas alcolicas
# Enviar esse BEB62362 para o setor de bebidas alcolicas
# Enviar esse BEB85146 para o setor de bebidas alcolicas
# Enviar esse BEB48898 para o setor de bebidas alcolicas
# Enviar esse BEB79496 para o setor de bebidas alcolicas
# Enviar esse BSA59251 para o setor de vinhos
# Enviar esse BEB15385 para o setor de bebidas alcolicas
# Enviar esse BEB24213 para o setor de bebidas alcolicas
# ...
