# %%
def minha_soma(numero1, numero2, numero3):
    return numero1 + numero2 + numero3

# funçao float converte a string em um numero decimal
# funçao int coverte a string em um numero inteiro
numero1 = float(input('Digite primeiro numero:'))   
numero2 = float(input('Digite segundo numero:'))
numero3 = float(input('Digite terceiro numero:'))
numero4 = int(input('Digite quarto numero:'))

soma = numero1 + numero2 + numero3 + numero4

print(soma)
# Out:
# 8.0
